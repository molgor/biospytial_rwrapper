# %% [markdown]
# # A notebook in R for modelling species distributions using the standard Maximum Entropy Model
#
# In this notebook we will compute the Maximum Entropy model for predicting species distributions using presence-only data. This method has been the cannonical model in predicting species records that lack real absences.
# For achiving this we will use the R package maxnet (cite article 2017, black box), an *Open Source* version of the MaxEnt java application used in earlier studies (Philips, et.al 2006).
#
# The MaxEnt model requires three data sources: i) environmental (covariates), ii) occurrence records (species presence) and ii) background sample (independent environmental locations).
# For the purposes of this comparison we will use the same background sample as in the Presence-only models (CAR).
#
# ## Caveats
# The MaxEnt model is a pointwise model
#
# No smapling bias , taken all data

# %%
library(dplyr)
library(purrr)
library(biospytial.rwrapper)
#install.packages('maxnet')
library(maxnet)

# %%
## Read adjancency matrix
mat_filename = "/outputs/training_data_sample_puebla_p9_abies_pinophyta_adjmat.npy"
library(reticulate)
np <- import("numpy")
M <- np$load(mat_filename)
TDF = read.csv("/outputs/training_data_sample_puebla_p9_abies_pinophyta.csv")
## Order it according to the id of the cell
## This is important because the adjancy matrix rows need to be the same
TDF = TDF[order(TDF$cell_ids),]
# Convert to numeric
TDF = mutate_at(TDF,vars(Dist.to.road_m,Elevation_m,MaxTemp_m,MeanTemp_m,MinTemp_m,Population_m,Precipitation_m,SolarRadiation_m,VaporPres_m,WindSp_m),as.numeric)
names(TDF) = lapply(names(TDF),function(x) gsub("_","",x))
names(TDF) = lapply(names(TDF),function(x) gsub("\\.","",x))
                    
### Mini script para borrar entrada con 0 neighbours
D = apply(M,MARGIN = 1,sum)
idx = match(0,D)
## Please check that the order is ok
# Checked, 
cell_with_no_neighbour = TDF$cellids[idx]
## look in the gis
## Erase idx for M and for TDF (Or maybe only for M)
M_bis = M[-c(idx),-c(idx)]

names(TDF)[23] <- 'covid2'
DataFrame = TDF %>% rowwise() %>% mutate(sample=pseudo_absence_naive(Plantae,LUCA),
                              species=pseudo_absence_naive(Pinophyta,Plantae))
                    
                    
formula_sample=sample~Disttoroadm+Populationm #+factor(tipos)
formula_presence=species~Elevationm+MeanTempm
n <- nrow(TDF)
trials <- rep(1,n)

burnin = 50000
n.sample = 100000
thin = 50

# %%
predictors = model.frame(formula = '~Elevationm + MeanTempm',data=DataFrame)
maxentm = maxnet(TDF$Pinophyta,predictors,maxnet.formula(TDF$Pinophyta,predictors,classes='l'))
pred_vals = predict(maxentm,predictors,type='cloglog')

# %% [markdown]
# ## K-fold cross validation

# %%
## Make ROC curve
library(pROC)
library('caret')
validate = createFolds(y = TDF$Pinophyta, k=7, returnTrain = FALSE)
# Out:
# Type 'citation("pROC")' for a citation.
#
# Attaching package: ‘pROC’
#
# The following objects are masked from ‘package:stats’:
#
#     cov, smooth, var
#
# Loading required package: lattice
# Loading required package: ggplot2
#
# Attaching package: ‘caret’
#
# The following object is masked from ‘package:purrr’:
#
#     lift

# %%
l <- list()
i = 1
for (fold in validate) {
    
    predictors = model.frame(formula = '~Elevationm + MeanTempm',data=DataFrame[fold])
    
    maxentm = maxnet(TDF$Pinophyta[fold],predictors,maxnet.formula(TDF$Pinophyta[fold],predictors,classes='l'))
    
    pred_vals = predict(maxentm,predictors,type='cloglog')
    
    
    observed.presences <- DataFrame$species[fold]
    ## Substitue by NA
    DataFrame$species[fold] <- NA
    results  <- joint.binomial.bymCARModel1(formula_S = formula_sample, 
                                        formula_P = formula_presence,
                                        n.sample=n.sample,
                                        data = DataFrame,
                                        burnin=burnin,
                                        postburnin=postburnin,
                                        thin=thin,
                                        verbose=TRUE) 

    DataFrame$species <- DataFrame$presences
    ## Return original values
    DataFrame$predicted_values_CV[fold] <- results$fitted.values[fold]
    predicted.probability = results$fitted.values[fold]
    pROC_obj <- roc(observed.presences,predicted.probability)

    l[[i]] <- pROC_obj
    i = i + 1
}
# Out:
# $Fold1
#   [1]   19   36   51   55   56   58   70   73   74   76   81   83   92  107  110
#  [16]  116  121  139  148  154  163  166  175  192  194  195  201  202  205  206
#  [31]  216  221  245  247  248  253  271  276  280  294  301  309  311  329  332
#  [46]  340  352  355  365  368  378  390  405  423  431  436  441  453  463  475
#  [61]  479  486  487  496  509  518  521  530  537  538  566  569  584  585  591
#  [76]  592  599  616  617  629  646  651  655  658  662  664  677  682  684  685
#  [91]  691  698  699  710  718  721  746  766  776  787  791  807  816  820  821
# [106]  833  834  841  845  853  855  857  885  889  903  906  911  913  919  920
# [121]  921  939  943  946  953  957  965  976  977  980  984  985  995  997 1009
# [136] 1010 1015 1017 1018 1034 1035 1037 1040 1046 1053 1061 1065 1081 1084 1101
# [151] 1103 1109 1113 1116 1117 1127 1133 1141 1142 1146 1148 1151 1155 1160 1165
# [166] 1180 1188 1198 1200 1204 1206 1211 1215 1218 1229 1231 1242 1243 1247 1252
# [181] 1262 1266 1273 1274 1282 1287 1298 1299 1300 1303 1304 1312 1317 1318 1332
# [196] 1337 1341 1363 1367 1381 1384 1396 1402 1407 1408 1413 1420 1435 1443 1458
# [211] 1459 1465 1467 1482 1493 1504 1513 1519 1522 1524 1532 1536 1538 1542 1551
# [226] 1557 1558 1564 1580 1583 1586 1615 1628 1638 1655 1659 1660 1667 1668 1673
# [241] 1676 1702 1708 1710 1716 1731 1737 1747 1754 1755 1778 1789 1801 1802 1823
# [256] 1827 1828 1830 1845 1847 1852 1862 1864 1877 1884 1896 1898 1906 1913 1943
# [271] 1947 1951 1955 1963 1965 1966 1969 1971 1973 1975 2028 2040 2042 2043 2051
# [286] 2062 2067 2069 2070 2071 2073 2074 2082 2084 2089 2092 2093 2102 2103 2104
# [301] 2113 2114 2130 2135 2143 2145 2150 2185 2191 2198 2201 2210 2217 2219 2221
# [316] 2222 2224 2227 2229 2237 2251 2252 2261 2266 2272 2273 2275 2279 2282 2297
# [331] 2315 2318 2319 2341 2343 2346 2347 2348 2352 2358 2360 2363 2371 2387 2389
# [346] 2412 2420 2432 2435 2436 2448 2450 2452 2465 2466 2468 2475 2490 2494 2502
# [361] 2505 2508 2512 2533 2535 2547 2554 2556 2559 2563 2568 2582 2586 2590 2591
# [376] 2598 2600 2603 2609 2622 2623 2624 2630 2648 2652 2656 2674 2676 2683 2695
# [391] 2699 2701 2719 2720 2733 2736 2740 2742 2770 2774 2780 2784 2791 2800 2813
# [406] 2825 2826 2828 2831 2836 2844 2874 2878 2880 2881 2911 2912 2913 2923 2928
# [421] 2931 2936 2947 2949 2951 2961 2976 2977 2981 2983 2989 2995 2996 3002 3004
# [436] 3005 3009 3015 3033 3034 3038 3049 3054 3063 3089 3096 3100 3101 3125 3127
# [451] 3133 3146 3150 3152 3163 3186 3190 3193 3196 3205 3218 3219 3220 3227 3235
# [466] 3238 3243 3245 3256 3261 3266 3275 3282 3301 3307 3317 3344 3347 3369 3372
# [481] 3385 3390 3392 3396 3402 3430 3431 3436 3441 3442 3444 3459 3474 3475 3496
# [496] 3497 3503 3510 3524 3527 3529 3534 3537 3539 3540 3546 3548 3576 3581 3584
# [511] 3596 3600 3601 3612 3613 3629 3639 3641 3649 3655 3661 3662 3677 3678 3693
# [526] 3725 3728 3732 3744 3748 3749 3757 3760 3768 3774 3783 3786 3788 3792 3794
# [541] 3796 3797 3798 3822 3823 3825 3827 3833 3845 3880 3882 3884 3888 3893 3900
# [556] 3907 3922 3934 3938 3947 3951 3955 3956 3966 3975 3982 3983 3995 4007 4008
# [571] 4013 4026 4035 4038 4039 4042 4046 4053 4059 4060
#
# $Fold2
#   [1]    4   13   15   16   27   29   32   34   39   40   53   60   75  112  125
#  [16]  130  133  135  136  138  140  149  150  151  153  164  169  170  177  183
#  [31]  199  215  217  225  226  233  272  278  279  302  316  333  334  337  347
#  [46]  348  349  362  370  377  398  403  407  410  414  418  427  445  447  451
#  [61]  452  472  476  477  489  493  495  505  513  533  539  543  546  548  558
#  [76]  560  565  579  595  598  600  601  605  609  622  625  656  672  676  679
#  [91]  683  688  693  696  714  724  729  736  739  745  750  754  774  775  786
# [106]  806  808  811  818  823  825  826  827  829  830  840  844  860  863  864
# [121]  874  875  876  882  886  891  894  897  900  905  909  931  935  936  940
# [136]  952  963  968  978  987 1001 1005 1008 1025 1041 1043 1052 1074 1082 1100
# [151] 1102 1111 1118 1119 1121 1124 1131 1139 1143 1147 1158 1166 1171 1175 1176
# [166] 1177 1178 1185 1190 1194 1212 1213 1217 1222 1226 1228 1238 1251 1254 1257
# [181] 1261 1275 1291 1292 1293 1294 1313 1315 1321 1330 1343 1347 1348 1359 1369
# [196] 1389 1394 1401 1403 1410 1412 1418 1426 1428 1433 1440 1441 1449 1450 1452
# [211] 1460 1461 1468 1469 1472 1480 1491 1492 1494 1495 1500 1501 1509 1511 1515
# [226] 1518 1521 1527 1531 1545 1550 1553 1562 1574 1581 1593 1597 1603 1604 1607
# [241] 1608 1609 1612 1616 1618 1619 1626 1640 1649 1656 1661 1663 1666 1669 1672
# [256] 1675 1677 1683 1698 1700 1712 1713 1734 1736 1746 1749 1751 1757 1768 1774
# [271] 1777 1780 1794 1815 1817 1818 1820 1821 1829 1835 1836 1843 1846 1849 1866
# [286] 1869 1871 1879 1886 1887 1891 1899 1903 1908 1914 1917 1923 1929 1952 1961
# [301] 1964 1977 1980 1986 1989 1993 1996 2005 2016 2021 2026 2031 2044 2054 2055
# [316] 2058 2063 2065 2106 2117 2131 2134 2138 2142 2151 2155 2166 2176 2179 2182
# [331] 2192 2195 2208 2209 2215 2218 2220 2226 2231 2234 2238 2258 2265 2267 2278
# [346] 2280 2281 2291 2295 2299 2301 2310 2325 2334 2353 2356 2361 2364 2369 2414
# [361] 2429 2444 2445 2449 2456 2459 2460 2462 2463 2464 2509 2553 2557 2560 2567
# [376] 2572 2576 2577 2579 2594 2602 2610 2617 2632 2635 2644 2645 2658 2661 2663
# [391] 2665 2668 2682 2700 2706 2716 2737 2747 2758 2760 2766 2778 2793 2798 2804
# [406] 2812 2816 2819 2821 2823 2846 2853 2855 2856 2866 2870 2877 2905 2935 2937
# [421] 2938 2941 2948 2964 2970 2971 2972 2982 2993 3008 3014 3024 3025 3031 3032
# [436] 3046 3052 3070 3073 3075 3077 3079 3086 3103 3104 3106 3110 3113 3129 3130
# [451] 3139 3142 3155 3156 3159 3162 3164 3167 3184 3189 3198 3199 3200 3212 3228
# [466] 3230 3231 3237 3242 3246 3248 3253 3254 3269 3279 3280 3293 3298 3299 3300
# [481] 3302 3303 3323 3329 3334 3340 3378 3383 3386 3398 3410 3414 3425 3429 3434
# [496] 3435 3443 3455 3457 3458 3469 3483 3490 3491 3495 3507 3509 3511 3521 3542
# [511] 3543 3552 3554 3560 3561 3565 3567 3568 3573 3593 3595 3598 3604 3607 3611
# [526] 3614 3624 3626 3642 3652 3657 3665 3676 3679 3689 3715 3723 3730 3734 3746
# [541] 3755 3763 3772 3780 3781 3790 3806 3811 3818 3829 3830 3848 3849 3862 3865
# [556] 3866 3868 3878 3879 3883 3885 3892 3895 3904 3908 3927 3931 3950 3954 3965
# [571] 3994 3999 4002 4029 4031 4045 4047 4051 4052 4055
#
# $Fold3
#   [1]    2    3    7    9   23   35   42   45   49   64   67   68   69   78   89
#  [16]  100  102  106  108  118  120  131  144  156  158  176  185  187  189  191
#  [31]  203  209  210  212  214  222  224  232  242  246  249  252  255  259  264
#  [46]  265  267  275  277  291  304  306  308  321  325  326  330  339  357  360
#  [61]  364  376  381  383  387  388  394  396  399  429  430  437  443  446  450
#  [76]  459  461  464  467  470  474  485  488  492  498  499  510  516  523  524
#  [91]  528  532  535  540  541  542  551  554  564  570  572  574  576  590  606
# [106]  607  608  611  613  619  620  636  645  659  694  706  722  725  731  744
# [121]  755  759  763  764  767  769  785  794  805  817  824  837  846  865  868
# [136]  869  870  877  879  902  912  916  926  927  942  945  948  954  956  958
# [151]  961  964  967  983  989  993  996 1000 1006 1013 1022 1023 1039 1045 1047
# [166] 1049 1054 1056 1058 1062 1066 1067 1069 1070 1071 1120 1125 1128 1132 1134
# [181] 1135 1144 1150 1154 1157 1159 1169 1183 1192 1197 1201 1202 1207 1221 1244
# [196] 1267 1270 1276 1289 1305 1309 1320 1322 1324 1325 1326 1336 1346 1350 1351
# [211] 1354 1392 1411 1415 1416 1422 1425 1432 1444 1446 1457 1464 1474 1477 1498
# [226] 1505 1514 1525 1533 1549 1555 1569 1571 1575 1582 1585 1598 1610 1622 1629
# [241] 1631 1632 1657 1671 1686 1692 1704 1705 1707 1711 1727 1761 1766 1771 1772
# [256] 1773 1781 1786 1796 1797 1806 1807 1808 1813 1822 1833 1870 1883 1895 1919
# [271] 1920 1925 1932 1934 1937 1938 1940 1967 1983 1992 1999 2004 2007 2013 2015
# [286] 2034 2035 2036 2041 2052 2060 2076 2083 2087 2088 2090 2094 2101 2108 2109
# [301] 2111 2129 2133 2136 2147 2149 2153 2168 2169 2171 2174 2175 2186 2187 2193
# [316] 2200 2204 2216 2245 2246 2248 2288 2294 2298 2309 2311 2312 2317 2322 2324
# [331] 2328 2330 2349 2355 2375 2376 2393 2395 2404 2407 2413 2417 2419 2433 2439
# [346] 2447 2451 2467 2469 2478 2485 2489 2491 2500 2504 2522 2532 2536 2542 2544
# [361] 2573 2575 2578 2583 2584 2593 2595 2604 2608 2612 2637 2638 2646 2651 2653
# [376] 2654 2660 2667 2677 2691 2693 2707 2709 2715 2738 2748 2749 2750 2752 2764
# [391] 2776 2782 2785 2786 2787 2797 2806 2808 2815 2817 2818 2822 2824 2830 2835
# [406] 2852 2861 2869 2872 2879 2893 2896 2902 2903 2907 2915 2917 2922 2924 2930
# [421] 2943 2944 2954 2958 2960 2973 2975 2986 2997 3003 3006 3011 3012 3023 3028
# [436] 3042 3048 3055 3081 3088 3094 3098 3108 3109 3121 3123 3124 3134 3160 3172
# [451] 3175 3180 3194 3204 3209 3221 3224 3240 3244 3249 3250 3252 3264 3267 3268
# [466] 3276 3289 3306 3309 3325 3331 3333 3336 3342 3350 3351 3355 3357 3363 3364
# [481] 3373 3375 3376 3379 3380 3389 3403 3407 3426 3440 3448 3454 3462 3471 3484
# [496] 3485 3487 3489 3498 3501 3508 3512 3513 3516 3528 3535 3536 3538 3541 3553
# [511] 3569 3575 3579 3588 3599 3615 3616 3620 3622 3627 3656 3658 3664 3667 3668
# [526] 3669 3671 3674 3684 3701 3707 3709 3717 3718 3719 3720 3736 3747 3751 3759
# [541] 3762 3773 3777 3778 3784 3787 3819 3826 3842 3858 3859 3861 3864 3897 3899
# [556] 3911 3915 3919 3933 3958 3959 3961 3962 3967 3968 3970 3971 3986 3991 3992
# [571] 4012 4017 4019 4022 4027 4028 4034 4036 4043 4050
#
# $Fold4
#   [1]   10   12   20   22   26   47   48   52   54   61   72   80   86   93   96
#  [16]   98  115  123  134  141  142  143  145  146  157  161  167  168  178  184
#  [31]  208  227  229  243  258  268  286  293  297  298  300  310  314  318  319
#  [46]  328  338  342  343  350  353  356  361  369  392  393  395  401  416  432
#  [61]  435  448  454  455  458  460  465  478  491  502  526  531  544  561  571
#  [76]  573  583  587  589  602  614  618  628  639  642  650  657  665  666  667
#  [91]  668  670  686  689  690  697  707  708  715  716  728  730  740  742  747
# [106]  765  773  778  780  783  789  790  792  795  796  801  802  812  815  828
# [121]  832  838  839  842  856  872  881  893  904  910  914  915  922  928  929
# [136]  944  949  972  974  979  990  992  994 1003 1004 1011 1012 1019 1021 1060
# [151] 1064 1079 1083 1089 1090 1096 1104 1129 1138 1149 1152 1181 1184 1189 1191
# [166] 1209 1216 1223 1225 1234 1245 1246 1271 1278 1283 1285 1296 1297 1306 1310
# [181] 1323 1333 1338 1339 1353 1360 1372 1376 1379 1380 1385 1386 1390 1391 1393
# [196] 1395 1397 1419 1429 1447 1456 1462 1463 1475 1478 1483 1496 1497 1510 1512
# [211] 1516 1520 1526 1528 1530 1540 1556 1561 1568 1572 1579 1590 1605 1613 1636
# [226] 1642 1648 1654 1658 1664 1665 1681 1687 1696 1697 1719 1722 1728 1743 1760
# [241] 1763 1770 1782 1792 1799 1803 1804 1805 1814 1826 1839 1840 1842 1853 1858
# [256] 1863 1880 1881 1882 1885 1892 1893 1894 1900 1902 1912 1915 1918 1930 1931
# [271] 1948 1954 1987 1991 1994 1997 1998 2000 2023 2038 2053 2056 2061 2075 2085
# [286] 2091 2095 2110 2112 2122 2132 2139 2157 2159 2167 2170 2172 2173 2178 2181
# [301] 2190 2196 2214 2233 2236 2242 2243 2255 2257 2259 2270 2283 2292 2304 2305
# [316] 2308 2314 2327 2336 2337 2340 2342 2351 2357 2373 2374 2379 2380 2382 2390
# [331] 2391 2392 2394 2397 2400 2401 2405 2408 2410 2415 2418 2421 2422 2423 2427
# [346] 2428 2430 2437 2441 2457 2461 2470 2471 2472 2486 2510 2515 2517 2520 2521
# [361] 2523 2524 2526 2530 2540 2548 2550 2561 2562 2570 2571 2611 2614 2615 2619
# [376] 2626 2628 2629 2640 2655 2662 2671 2679 2688 2703 2704 2711 2712 2722 2724
# [391] 2725 2732 2746 2753 2755 2768 2777 2794 2809 2820 2848 2849 2850 2860 2863
# [406] 2898 2899 2921 2940 2942 2956 2957 2962 2965 2967 2968 2979 2988 3010 3018
# [421] 3030 3037 3041 3043 3047 3062 3064 3067 3069 3082 3090 3091 3092 3093 3095
# [436] 3112 3114 3119 3126 3131 3137 3141 3144 3151 3154 3157 3158 3170 3171 3179
# [451] 3182 3185 3187 3192 3206 3207 3210 3215 3216 3232 3255 3260 3265 3270 3272
# [466] 3281 3283 3287 3291 3294 3295 3304 3311 3319 3321 3330 3349 3384 3387 3388
# [481] 3394 3399 3400 3404 3405 3408 3412 3417 3424 3428 3433 3445 3453 3467 3479
# [496] 3480 3488 3494 3500 3505 3506 3520 3523 3559 3564 3566 3572 3577 3585 3621
# [511] 3628 3632 3637 3645 3646 3648 3659 3687 3688 3691 3692 3698 3703 3710 3711
# [526] 3712 3713 3721 3722 3735 3739 3741 3752 3758 3766 3775 3789 3791 3800 3803
# [541] 3804 3805 3815 3817 3824 3828 3831 3835 3837 3839 3840 3843 3853 3855 3857
# [556] 3886 3887 3894 3896 3901 3902 3913 3914 3921 3925 3936 3940 3944 3979 3980
# [571] 3981 3985 3988 3990 4001 4010 4020 4021 4032 4049
#
# $Fold5
#   [1]    5    6   11   21   24   28   33   37   46   59   88   90   95  101  124
#  [16]  127  128  137  152  159  171  172  179  181  196  204  218  219  230  235
#  [31]  240  251  257  261  263  266  269  273  281  282  283  285  289  292  296
#  [46]  322  323  327  341  346  351  354  367  374  384  386  389  397  404  406
#  [61]  411  417  420  433  434  438  442  449  457  500  511  515  517  522  525
#  [76]  529  536  547  555  556  557  581  586  594  597  604  630  631  635  638
#  [91]  641  643  648  653  669  671  687  692  695  700  703  704  719  727  733
# [106]  741  749  756  757  758  762  768  772  781  782  788  793  799  800  803
# [121]  813  814  819  822  835  849  850  851  852  854  862  873  878  888  895
# [136]  901  918  932  951  959  981  991  998 1016 1026 1028 1031 1036 1044 1048
# [151] 1055 1057 1063 1073 1076 1078 1091 1097 1106 1107 1108 1115 1130 1137 1140
# [166] 1156 1161 1162 1163 1168 1187 1195 1196 1224 1227 1230 1248 1250 1256 1260
# [181] 1277 1288 1290 1295 1308 1311 1314 1316 1319 1327 1328 1329 1334 1342 1357
# [196] 1358 1362 1366 1370 1378 1382 1388 1399 1404 1409 1421 1430 1431 1439 1445
# [211] 1448 1453 1471 1476 1488 1499 1517 1523 1529 1539 1544 1546 1554 1566 1587
# [226] 1589 1594 1614 1623 1633 1634 1645 1646 1653 1674 1678 1679 1689 1690 1695
# [241] 1721 1724 1725 1732 1735 1740 1742 1745 1748 1753 1764 1767 1776 1779 1783
# [256] 1784 1790 1798 1809 1810 1812 1819 1824 1838 1841 1851 1856 1861 1865 1872
# [271] 1874 1888 1904 1909 1924 1944 1945 1949 1950 1956 1962 1968 1972 1978 1979
# [286] 1982 1984 1985 1990 2001 2002 2006 2010 2014 2020 2022 2027 2030 2033 2037
# [301] 2046 2048 2049 2050 2064 2068 2072 2077 2099 2115 2119 2121 2125 2126 2140
# [316] 2158 2160 2161 2177 2180 2184 2189 2207 2225 2239 2247 2250 2253 2254 2269
# [331] 2277 2284 2285 2286 2287 2289 2290 2296 2302 2321 2331 2333 2350 2359 2362
# [346] 2368 2370 2378 2388 2399 2402 2409 2411 2425 2434 2442 2443 2455 2473 2477
# [361] 2481 2483 2484 2496 2497 2503 2514 2525 2529 2538 2539 2546 2574 2587 2589
# [376] 2597 2601 2605 2642 2649 2659 2664 2672 2678 2680 2685 2689 2696 2702 2735
# [391] 2739 2743 2745 2767 2790 2796 2799 2802 2803 2807 2811 2829 2832 2833 2834
# [406] 2843 2847 2851 2876 2882 2883 2886 2890 2892 2895 2897 2906 2918 2919 2926
# [421] 2952 2978 2980 2985 2991 2992 3000 3021 3027 3036 3039 3044 3051 3060 3061
# [436] 3071 3072 3080 3087 3097 3102 3111 3140 3145 3147 3161 3166 3168 3169 3174
# [451] 3178 3181 3183 3201 3203 3214 3223 3229 3239 3251 3258 3263 3278 3285 3290
# [466] 3292 3296 3297 3315 3328 3335 3341 3343 3346 3348 3352 3353 3359 3366 3371
# [481] 3397 3411 3415 3421 3446 3456 3461 3466 3470 3472 3477 3493 3504 3518 3519
# [496] 3526 3531 3533 3547 3555 3557 3563 3570 3571 3574 3578 3580 3582 3586 3587
# [511] 3594 3606 3609 3610 3634 3636 3640 3643 3666 3670 3675 3680 3681 3683 3686
# [526] 3697 3700 3705 3714 3726 3727 3738 3743 3745 3750 3756 3764 3767 3770 3771
# [541] 3776 3799 3801 3810 3813 3814 3820 3836 3860 3871 3872 3875 3876 3891 3903
# [556] 3905 3909 3912 3920 3932 3935 3942 3945 3946 3952 3953 3957 3963 3972 3973
# [571] 3977 3993 4000 4006 4011 4016 4041 4048 4054 4057
#
# $Fold6
#   [1]    1    8   17   25   30   38   43   50   63   65   66   71   77   79   84
#  [16]   87   94   97   99  104  109  111  113  114  119  122  132  173  182  200
#  [31]  211  213  220  228  234  237  238  239  241  244  250  254  256  260  270
#  [46]  274  290  305  312  313  315  317  336  366  371  379  380  382  400  402
#  [61]  408  409  412  424  425  444  456  469  480  481  482  484  494  503  504
#  [76]  506  507  514  520  549  550  553  568  575  580  582  588  596  610  615
#  [91]  623  627  649  654  673  675  678  681  709  711  712  713  717  720  732
# [106]  734  735  737  738  743  748  760  761  770  771  797  798  809  810  836
# [121]  847  858  859  861  866  871  883  890  898  907  908  917  924  925  933
# [136]  934  938  947  950  960  970  973  982  988 1002 1007 1014 1020 1024 1027
# [151] 1030 1032 1038 1050 1051 1068 1072 1075 1077 1080 1085 1087 1088 1094 1099
# [166] 1114 1122 1123 1136 1153 1167 1172 1173 1186 1193 1205 1214 1219 1220 1232
# [181] 1233 1236 1240 1241 1249 1255 1259 1263 1264 1272 1281 1284 1307 1355 1364
# [196] 1365 1368 1373 1383 1398 1423 1424 1427 1434 1442 1451 1454 1473 1481 1484
# [211] 1486 1506 1508 1537 1541 1543 1547 1560 1565 1573 1577 1578 1588 1591 1592
# [226] 1599 1602 1606 1617 1621 1627 1630 1637 1647 1651 1670 1680 1684 1685 1688
# [241] 1691 1699 1701 1706 1709 1714 1718 1720 1729 1730 1739 1750 1756 1759 1765
# [256] 1769 1785 1787 1788 1791 1800 1816 1848 1854 1855 1857 1859 1860 1868 1875
# [271] 1878 1889 1897 1901 1905 1907 1910 1921 1926 1927 1928 1933 1935 1939 1958
# [286] 1959 1970 1974 1981 2003 2008 2009 2017 2019 2029 2039 2059 2086 2097 2098
# [301] 2107 2116 2118 2127 2144 2148 2152 2154 2156 2165 2188 2199 2202 2205 2206
# [316] 2211 2213 2235 2249 2256 2262 2268 2274 2300 2303 2307 2320 2323 2329 2335
# [331] 2344 2365 2366 2372 2377 2381 2383 2384 2386 2398 2403 2416 2440 2446 2482
# [346] 2492 2498 2499 2501 2506 2511 2513 2518 2519 2528 2531 2541 2551 2552 2555
# [361] 2565 2566 2592 2596 2618 2620 2621 2627 2633 2634 2636 2639 2641 2643 2670
# [376] 2673 2684 2686 2687 2694 2697 2705 2708 2714 2717 2718 2723 2727 2729 2734
# [391] 2741 2744 2754 2756 2757 2761 2763 2765 2772 2773 2775 2783 2792 2795 2838
# [406] 2839 2841 2854 2865 2873 2875 2887 2894 2900 2901 2909 2914 2916 2927 2934
# [421] 2945 2946 2950 2966 2984 2998 2999 3013 3016 3017 3022 3029 3040 3050 3056
# [436] 3059 3065 3068 3083 3085 3107 3116 3117 3136 3143 3148 3165 3195 3208 3211
# [451] 3233 3234 3247 3257 3262 3284 3288 3305 3312 3313 3316 3320 3322 3324 3326
# [466] 3332 3338 3345 3354 3360 3361 3367 3368 3374 3382 3393 3395 3401 3406 3409
# [481] 3413 3419 3423 3439 3447 3450 3460 3465 3468 3473 3476 3478 3481 3486 3499
# [496] 3514 3515 3545 3550 3551 3556 3558 3590 3591 3602 3603 3605 3617 3618 3619
# [511] 3623 3625 3633 3635 3644 3650 3651 3653 3663 3672 3673 3685 3690 3694 3695
# [526] 3699 3702 3706 3724 3729 3737 3740 3742 3753 3754 3779 3782 3785 3793 3795
# [541] 3807 3809 3832 3834 3844 3846 3851 3852 3867 3869 3877 3890 3898 3910 3916
# [556] 3917 3928 3929 3937 3939 3943 3960 3969 3974 3976 3978 3984 3996 3998 4004
# [571] 4009 4023 4024 4025 4030 4033 4037 4040 4044 4058
#
# $Fold7
#   [1]   14   18   31   41   44   57   62   82   85   91  103  105  117  126  129
#  [16]  147  155  160  162  165  174  180  186  188  190  193  197  198  207  223
#  [31]  231  236  262  284  287  288  295  299  303  307  320  324  331  335  344
#  [46]  345  358  359  363  372  373  375  385  391  413  415  419  421  422  426
#  [61]  428  439  440  462  466  468  471  473  483  490  497  501  508  512  519
#  [76]  527  534  545  552  559  562  563  567  577  578  593  603  612  621  624
#  [91]  626  632  633  634  637  640  644  647  652  660  661  663  674  680  701
# [106]  702  705  723  726  751  752  753  777  779  784  804  831  843  848  867
# [121]  880  884  887  892  896  899  923  930  937  941  955  962  966  969  971
# [136]  975  986  999 1029 1033 1042 1059 1086 1092 1093 1095 1098 1105 1110 1112
# [151] 1126 1145 1164 1170 1174 1179 1182 1199 1203 1208 1210 1235 1237 1239 1253
# [166] 1258 1265 1268 1269 1279 1280 1286 1301 1302 1331 1335 1340 1344 1345 1349
# [181] 1352 1356 1361 1371 1374 1375 1377 1387 1400 1405 1406 1414 1417 1436 1437
# [196] 1438 1455 1466 1470 1479 1485 1487 1489 1490 1502 1503 1507 1534 1535 1548
# [211] 1552 1559 1563 1567 1570 1576 1584 1595 1596 1600 1601 1611 1620 1624 1625
# [226] 1635 1639 1641 1643 1644 1650 1652 1662 1682 1693 1694 1703 1715 1717 1723
# [241] 1726 1733 1738 1741 1744 1752 1758 1762 1775 1793 1795 1811 1825 1831 1832
# [256] 1834 1837 1844 1850 1867 1873 1876 1890 1911 1916 1922 1936 1941 1942 1946
# [271] 1953 1957 1960 1976 1988 1995 2011 2012 2018 2024 2025 2032 2045 2047 2057
# [286] 2066 2078 2079 2080 2081 2096 2100 2105 2120 2123 2124 2128 2137 2141 2146
# [301] 2162 2163 2164 2183 2194 2197 2203 2212 2223 2228 2230 2232 2240 2241 2244
# [316] 2260 2263 2264 2271 2276 2293 2306 2313 2316 2326 2332 2338 2339 2345 2354
# [331] 2367 2385 2396 2406 2424 2426 2431 2438 2453 2454 2458 2474 2476 2479 2480
# [346] 2487 2488 2493 2495 2507 2516 2527 2534 2537 2543 2545 2549 2558 2564 2569
# [361] 2580 2581 2585 2588 2599 2606 2607 2613 2616 2625 2631 2647 2650 2657 2666
# [376] 2669 2675 2681 2690 2692 2698 2710 2713 2721 2726 2728 2730 2731 2751 2759
# [391] 2762 2769 2771 2779 2781 2788 2789 2801 2805 2810 2814 2827 2837 2840 2842
# [406] 2845 2857 2858 2859 2862 2864 2867 2868 2871 2884 2885 2888 2889 2891 2904
# [421] 2908 2910 2920 2925 2929 2932 2933 2939 2953 2955 2959 2963 2969 2974 2987
# [436] 2990 2994 3001 3007 3019 3020 3026 3035 3045 3053 3057 3058 3066 3074 3076
# [451] 3078 3084 3099 3105 3115 3118 3120 3122 3128 3132 3135 3138 3149 3153 3173
# [466] 3176 3177 3188 3191 3197 3202 3213 3217 3222 3225 3226 3236 3241 3259 3271
# [481] 3273 3274 3277 3286 3308 3310 3314 3318 3327 3337 3339 3356 3358 3362 3365
# [496] 3370 3377 3381 3391 3416 3418 3420 3422 3427 3432 3437 3438 3449 3451 3452
# [511] 3463 3464 3482 3492 3502 3517 3522 3525 3530 3532 3544 3549 3562 3583 3589
# [526] 3592 3597 3608 3630 3631 3638 3647 3654 3660 3682 3696 3704 3708 3716 3731
# [541] 3733 3761 3765 3769 3802 3808 3812 3816 3821 3838 3841 3847 3850 3854 3856
# [556] 3863 3870 3873 3874 3881 3889 3906 3918 3923 3924 3926 3930 3941 3948 3949
# [571] 3964 3987 3989 3997 4003 4005 4014 4015 4018 4056 4061

# %%
## Save to posterity
chain = cbind(TDF$cellids,pred_vals)
colnames(chain) <- c("cellids", "maxentPines")
file_ = '/outputs/presence_only_models/maxent_pines2.csv'

write.csv(chain,file_)

# %% [markdown]
# ## Here put the evaluations code

# %%
install.packages('sdm')
# Out:
# Warning message in install.packages("sdm"):
# “installation of package ‘sdm’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library('sdm')
# Out:
# Error in library("sdm"): there is no package called ‘sdm’
# Traceback:
#
# 1. library("sdm")
# 2. stop(txt, domain = NA)

# %%
hist(pred_vals)
# Out:
# Plot with title “Histogram of pred_vals”

# %%
summary(me_mod)
# Out:
#                Length Class     Mode
# a0             200    -none-    numeric
# beta           400    dgCMatrix S4
# df             200    -none-    numeric
# dim              2    -none-    numeric
# lambda         200    -none-    numeric
# dev.ratio      200    -none-    numeric
# nulldev          1    -none-    numeric
# npasses          1    -none-    numeric
# jerr             1    -none-    numeric
# offset           1    -none-    logical
# classnames       2    -none-    character
# call             8    -none-    call
# nobs             1    -none-    numeric
# betas            2    -none-    numeric
# alpha            1    -none-    numeric
# entropy          1    -none-    numeric
# penalty.factor   2    -none-    numeric
# featuremins      2    -none-    numeric
# featuremaxs      2    -none-    numeric
# varmin           2    -none-    numeric
# varmax           2    -none-    numeric
# samplemeans      2    -none-    list
# levels           2    -none-    list

# %%
data(bradypus)
p <- bradypus$presence
data <- bradypus[,-1]
mod <- maxnet(p, data)
plot(mod, type="cloglog")
mod <- maxnet(p, data, maxnet.formula(p, data, classes="lq"))
plot(mod, "tmp6190_ann")
# Out:
# plot without title
# plot without title

# %%
bradypus
# Out:
#      presence cld6190_ann dtr6190_ann ecoreg frs6190_ann h_dem pre6190_ann
# 1    1        76          104         10     2           121   46
# 2    1        76          104         10     2           121   46
# 3    1        57          114         10     1           211   65
# 4    1        57          112         10     3           363   36
# 5    1        57          113         10     3           303   39
# 6    1        58          111         10     0           166   54
# 7    1        57          110         8      0           430   33
# 8    1        77           82         10     0            12   60
# 9    1        83           86         10     0            23   58
# 10   1        82           85         10     0            32   62
# 11   1        77           95         10     0            47   70
# 12   1        82           85         10     0            34   61
# 13   1        82           90         10     0            34   61
# 14   1        66           93         10     1            29   33
# 15   1        81           99         10     0            46   56
# 16   1        75           86         10     0             7   76
# 17   1        76           91         10     0            48   54
# 18   1        79           92         10     0            19   65
# 19   1        76           94         10     0           101   55
# 20   1        77           94         10     0            91   55
# 21   1        76           93         10     0            17   55
# 22   1        71           92         10     0            16   55
# 23   1        66           92         10     0            10   55
# 24   1        77           94         10     0            35   55
# 25   1        77           94         10     0            31   55
# 26   1        78          100         10     0             6   66
# 27   1        77           99         10     0             1   68
# 28   1        77           99         10     0             3   67
# 29   1        75           95         10     3           771   42
# 30   1        82           96         10     0            86   74
# ⋮    ⋮        ⋮           ⋮           ⋮      ⋮           ⋮     ⋮
# 1087 0        50          137         5      143         1232   4
# 1088 0        65          110         9        0          189  41
# 1089 0        43          127         9        3           49  30
# 1090 0        74           89         10       1          305  61
# 1091 0        58           85         10       0            3  51
# 1092 0        47          124         5       19           35  28
# 1093 0        63          110         9        0          631  39
# 1094 0        70           91         10       1           77  68
# 1095 0        82           94         10       0           77  60
# 1096 0        82           95         10       1           79  68
# 1097 0        66          118         10       0          315  38
# 1098 0        62           98         10       0           67  59
# 1099 0        44          111         9        2           60  34
# 1100 0        69           94         10       6         2412  33
# 1101 0        67          103         10       2         1219  52
# 1102 0        82           96         10       0           83  74
# 1103 0        70          111         10       4          606  26
# 1104 0        46          140         5       38           94  19
# 1105 0        51           63         3       39           16  47
# 1106 0        44          120         9        1           69  33
# 1107 0        62          120         9        0          894  31
# 1108 0        67          119         11       0          113  36
# 1109 0        69          100         10       0          353  37
# 1110 0        67          123         9        1          375  47
# 1111 0        61          121         9        0          604  39
# 1112 0        46          143         5      112         1040   6
# 1113 0        74           93         10       0          134  75
# 1114 0        74           93         10       0           63  75
# 1115 0        62          107         2        1          648  23
# 1116 0        50          161         12     133         3624   5
#      pre6190_l1 pre6190_l10 pre6190_l4 pre6190_l7 tmn6190_ann tmp6190_ann
# 1     84        41           54         3         192         266
# 2     84        40           54         3         192         266
# 3    129        56           58        34         140         244
# 4     71        33           27        13         135         229
# 5     77        35           29        15         134         229
# 6    107        48           45        23         156         252
# 7     61        30           29        15         153         245
# 8     69        24           96        42         229         275
# 9     96        30           95        25         220         271
# 10    84        39           98        29         224         272
# 11    72        50           92        69         211         264
# 12    85        39           98        29         224         272
# 13    78        54           94        29         216         268
# 14    51        42           28        18         167         243
# 15    80        23          103        26         203         264
# 16   116        20          138        49         222         268
# 17    70        20           99        27         217         267
# 18    75        17          120        56         221         270
# 19    63        17          101        31         207         264
# 20    67        23           89        27         211         268
# 21    64        19           98        30         208         264
# 22    64        17          102        30         212         265
# 23    61        15          105        35         213         266
# 24    64        20           96        29         208         265
# 25    66        22           91        28         209         267
# 26   108        26          120        31         212         268
# 27   110        28          119        36         213         268
# 28   109        27          120        33         213         268
# 29    79        42           29        15         108         195
# 30    96        81           97        39         206         260
# ⋮    ⋮          ⋮           ⋮          ⋮          ⋮           ⋮
# 1087  2          2            4          5        -49          72
# 1088 79         38           37          6        179         266
# 1089 41         32           38          9         77         202
# 1090 67         15          100         63        207         255
# 1091 65          4          122         26        220         273
# 1092 41         35           28         15         49         167
# 1093 83         43           31          2        146         234
# 1094 78         22           92         75        209         257
# 1095 95         41           94         17        210         267
# 1096 97         64           95         24        205         265
# 1097 73         35           34          4        168         261
# 1098 10         80           54         90        215         271
# 1099 40         40           47         15         92         204
# 1100 14         56           53         20         82         138
# 1101 33         79           79         24        172         225
# 1102 97         81           96         37        207         260
# 1103 49         35           18          6        137         225
# 1104 27         26           19          7         20         160
# 1105 30         36           48         72         46         100
# 1106 48         34           48         12         94         210
# 1107 70         38           17          2        127         227
# 1108 73         31           35          6        164         265
# 1109 58         48           33         14        120         208
# 1110 98         49           37          1        156         257
# 1111 86         48           23          4        137         234
# 1112  4          5            5          7        -31          98
# 1113 20         73           78        127        213         264
# 1114 82         54           95         71        206         259
# 1115 37          5           52          3        190         260
# 1116 14          1            1          0        -40          94
#      tmx6190_ann vap6190_ann
# 1    337         279
# 2    337         279
# 3    321         221
# 4    307         202
# 5    306         202
# 6    326         235
# 7    326         217
# 8    335         306
# 9    328         301
# 10   328         300
# 11   318         298
# 12   328         300
# 13   324         306
# 14   319         252
# 15   327         295
# 16   325         301
# 17   331         294
# 18   332         305
# 19   326         295
# 20   330         305
# 21   327         297
# 22   329         294
# 23   329         292
# 24   327         299
# 25   329         302
# 26   330         306
# 27   329         304
# 28   329         306
# 29   274         179
# 30   316         302
# ⋮    ⋮           ⋮
# 1087 224          45
# 1088 345         258
# 1089 332         177
# 1090 319         267
# 1091 329         280
# 1092 311         144
# 1093 308         197
# 1094 321         233
# 1095 330         303
# 1096 324         305
# 1097 342         255
# 1098 335         286
# 1099 324         179
# 1100 195         130
# 1101 288         210
# 1102 317         304
# 1103 306         215
# 1104 321         123
# 1105 168         103
# 1106 331         186
# 1107 302         193
# 1108 335         261
# 1109 286         168
# 1110 338         243
# 1111 310         204
# 1112 260          58
# 1113 338         281
# 1114 313         295
# 1115 337         210
# 1116 201          55

# %%
maxnet.formula(presences,predictors,classes="l")
# Out:
# ~sample + Disttoroadm + Populationm - 1
# <environment: 0x7f15e4a7b6c0>

# %%
names(data)
# Out:
#  [1] "cld6190_ann" "dtr6190_ann" "ecoreg"      "frs6190_ann" "h_dem"
#  [6] "pre6190_ann" "pre6190_l1"  "pre6190_l10" "pre6190_l4"  "pre6190_l7"
# [11] "tmn6190_ann" "tmp6190_ann" "tmx6190_ann" "vap6190_ann"

# %%
subset(TDF, select=-Pinophyta)
# Out:
#      X    LUCA Plantae Abies cellids Disttoroadm Elevationm MaxTempm MeanTempm
# 1     632 0    0       0     233546   277        3029       2353     2264
# 2    3609 1    1       0     233547  2556        1133       2332     2330
# 3    2780 1    1       0     233548  3242           4       2305     2387
# 4    1488 0    0       0     233549   204           2       2194     3095
# 5     415 0    0       0     233550   553           5       2113     2274
# 6    3888 1    0       0     233551   906           9       2127     2274
# 7    2057 1    0       0     233552  1120        1409       2150     2274
# 8    2277 0    0       0     233553  3392        3630       4052     3095
# 9     421 0    0       0     233747   279        3320       2643     2406
# 10   3367 1    1       0     233748   197        3349       2485     2328
# 11   2365 0    0       0     233749  1428        3398       2425     2302
# 12   1430 0    0       0     233750    17        3132       2431     2310
# 13    251 1    1       0     233751  1572        2735       2449     2357
# 14   3093 1    0       0     233752  2490        3244       2405     2423
# 15   1576 0    0       0     233753  2984           6       2229     2391
# 16   2929 1    0       0     233754  3369        2783       2141     2274
# 17   3958 1    0       0     233755   469        1412       2202     2274
# 18   1018 0    0       0     233756   733           8       2217     2274
# 19   3038 0    0       0     233952  2476        3592       2819     2290
# 20   2318 0    0       0     233953   519          72       2714     2294
# 21   3170 0    0       0     233954  1288        3550       2596     2311
# 22    192 1    1       0     233955  3355        3597       2518     2318
# 23   1271 1    1       0     233956   872         665       2386     2259
# 24   2099 1    1       0     233957  3370        3425       2491     2317
# 25   3922 0    0       0     233958  1180        3563       2440     2295
# 26    454 0    0       0     233959  1208        3053       2495     2343
# 27   1509 1    1       0     233960   559          14       2459     2373
# 28   3966 1    0       0     233961  1508           6       2338     2412
# 29   2689 1    1       0     233962  2808           1       2215     2283
# 30   1570 0    0       0     233963    12        1406       2252     2277
# ⋮    ⋮    ⋮    ⋮       ⋮     ⋮       ⋮           ⋮          ⋮        ⋮
# 4032 1853 1    1       0     254059  2585        1943        745      725
# 4033 1025 1    1       0     254060   862        2147        457      577
# 4034 3013 1    1       0     254061  1693        1685        587      763
# 4035 3945 1    1       0     254062  3008        1531       1014     1132
# 4036  612 1    1       0     254063  3112        1062       2011     1531
# 4037 1792 1    1       0     254064  1606        1574        980     1130
# 4038 1913 1    1       0     254065   879        1242       1952     1534
# 4039  961 1    1       0     254066  2586         696       3186     2100
# 4040 3809 1    1       0     254067  3145         346       2920     1952
# 4041 2537 1    0       0     254068  2440        1312        731     1052
# 4042 1651 1    0       0     254069     2        2457         76      178
# 4043  732 1    1       0     254070   965        1571        727      938
# 4044   93 1    1       0     254326  2043        2287        905      838
# 4045 1417 1    1       0     254327  2406        1664       1366     1133
# 4046 2249 1    1       0     254328   971        1736       1077      952
# 4047 2904 1    1       0     254329  3220        1859        993      839
# 4048 1948 1    1       0     254330   241        1938        992      806
# 4049  753 1    1       0     254331  2152        2295        479      567
# 4050 3547 1    1       0     254332  1396        1761        982      914
# 4051 2617 1    1       0     254333   202        1596       1336     1082
# 4052 1675 1    1       0     254334  1061        1576       1365     1123
# 4053  985 1    1       0     254335  1239        1769        957      927
# 4054 3847 1    1       0     254336  3261        1971        684      775
# 4055 3435 1    1       0     254337  1854        1629        956      964
# 4056  441 1    1       0     254338  3158         996       1984     1489
# 4057 1250 1    1       0     254339  3218        1214       1917     1506
# 4058 2077 1    1       0     254340  2267        1666        594      926
# 4059 2148 1    1       0     254341    83        1594        908     1142
# 4060 3230 1    1       0     254342  2258         824       2914     1909
# 4061  510 1    1       0     254343  3267         362       3159     2027
#      MinTempm ⋯ WindSpm Longitude Latitude wwfmhtnum
# 1    1990     ⋯  799    -97.65156 21.46739  1
# 2    1971     ⋯  885    -97.60256 21.46739  1
# 3    1956     ⋯  885    -97.55356 21.46739 NA
# 4    3197     ⋯ 1050    -97.50456 21.46739 14
# 5    1765     ⋯  885    -97.45556 21.46739 NA
# 6    1781     ⋯  885    -97.40656 21.46739 14
# 7    1801     ⋯  885    -97.36443 21.46926 14
# 8    3197     ⋯ 1050    -97.22934 21.47248 NA
# 9    2174     ⋯  440    -97.79856 21.41839  1
# 10   2069     ⋯  512    -97.74956 21.41839  1
# 11   2035     ⋯  601    -97.70056 21.41839  1
# 12   2030     ⋯  714    -97.65156 21.41839  1
# 13   2037     ⋯  833    -97.60256 21.41839  1
# 14   2011     ⋯  882    -97.55356 21.41839 14
# 15   1897     ⋯  885    -97.50456 21.41839 14
# 16   1784     ⋯  885    -97.45556 21.41839 14
# 17   1844     ⋯  885    -97.40656 21.41839 14
# 18   1865     ⋯  885    -97.37337 21.42418 14
# 19   2302     ⋯  355    -97.94556 21.36939  1
# 20   2231     ⋯  355    -97.89656 21.36939  1
# 21   2150     ⋯  355    -97.84756 21.36939  1
# 22   2116     ⋯  364    -97.79856 21.36939  1
# 23   2010     ⋯  456    -97.74956 21.36939  1
# 24   2083     ⋯  531    -97.70056 21.36939  1
# 25   2043     ⋯  621    -97.65156 21.36939  1
# 26   2079     ⋯  724    -97.60256 21.36939  1
# 27   2046     ⋯  860    -97.55356 21.36939  1
# 28   1969     ⋯  885    -97.50456 21.36939 14
# 29   1855     ⋯  885    -97.45556 21.36939 NA
# 30   1899     ⋯  885    -97.41159 21.37262 14
# ⋮    ⋮        ⋱ ⋮       ⋮         ⋮        ⋮
# 4032  652     ⋯ 626     -97.21056 17.54739 3
# 4033  417     ⋯ 735     -97.16156 17.54739 3
# 4034  527     ⋯ 702     -97.11256 17.54739 3
# 4035  865     ⋯ 623     -97.06356 17.54739 3
# 4036 1683     ⋯ 503     -97.01456 17.54739 2
# 4037  837     ⋯ 629     -96.96556 17.54739 3
# 4038 1629     ⋯ 540     -96.91656 17.54739 2
# 4039 2588     ⋯ 459     -96.86756 17.54739 2
# 4040 2372     ⋯ 470     -96.81856 17.54739 2
# 4041  649     ⋯ 634     -96.76956 17.54739 3
# 4042   74     ⋯ 841     -96.72056 17.54739 3
# 4043  644     ⋯ 652     -96.67156 17.54739 3
# 4044  778     ⋯ 587     -97.65156 17.49839 3
# 4045 1162     ⋯ 493     -97.60256 17.49839 3
# 4046  925     ⋯ 547     -97.55356 17.49839 3
# 4047  846     ⋯ 568     -97.50456 17.49839 3
# 4048  852     ⋯ 581     -97.45556 17.49839 3
# 4049  441     ⋯ 692     -97.40656 17.49839 3
# 4050  840     ⋯ 578     -97.35756 17.49839 2
# 4051 1142     ⋯ 573     -97.30856 17.49839 2
# 4052 1152     ⋯ 578     -97.25956 17.49839 2
# 4053  826     ⋯ 608     -97.21056 17.49839 2
# 4054  603     ⋯ 653     -97.16156 17.49839 2
# 4055  814     ⋯ 610     -97.11256 17.49839 3
# 4056 1660     ⋯ 519     -97.06356 17.49839 2
# 4057 1605     ⋯ 537     -97.01456 17.49839 2
# 4058  533     ⋯ 689     -96.96556 17.49839 3
# 4059  778     ⋯ 619     -96.91656 17.49839 3
# 4060 2368     ⋯ 495     -96.86756 17.49839 2
# 4061 2567     ⋯ 481     -96.81856 17.49839 2
#      wwfmhtnam                                        covid
# 1    Tropical and Subtropical Moist Broadleaf Forests  42818
# 2    Tropical and Subtropical Moist Broadleaf Forests 114294
# 3    NaN                                               24618
# 4    Mangroves                                         87982
# 5    NaN                                               24618
# 6    Mangroves                                         24618
# 7    Mangroves                                         42560
# 8    NaN                                               17499
# 9    Tropical and Subtropical Moist Broadleaf Forests  73992
# 10   Tropical and Subtropical Moist Broadleaf Forests  42818
# 11   Tropical and Subtropical Moist Broadleaf Forests  42818
# 12   Tropical and Subtropical Moist Broadleaf Forests  42818
# 13   Tropical and Subtropical Moist Broadleaf Forests  42818
# 14   Mangroves                                         42818
# 15   Mangroves                                         87982
# 16   Mangroves                                         87983
# 17   Mangroves                                        114280
# 18   Mangroves                                         42560
# 19   Tropical and Subtropical Moist Broadleaf Forests  42818
# 20   Tropical and Subtropical Moist Broadleaf Forests  73935
# 21   Tropical and Subtropical Moist Broadleaf Forests  42818
# 22   Tropical and Subtropical Moist Broadleaf Forests  42818
# 23   Tropical and Subtropical Moist Broadleaf Forests  42818
# 24   Tropical and Subtropical Moist Broadleaf Forests  42818
# 25   Tropical and Subtropical Moist Broadleaf Forests  42818
# 26   Tropical and Subtropical Moist Broadleaf Forests  42818
# 27   Tropical and Subtropical Moist Broadleaf Forests  42818
# 28   Mangroves                                         87010
# 29   NaN                                               87983
# 30   Mangroves                                         42560
# ⋮    ⋮                                                ⋮
# 4032 Tropical and Subtropical Coniferous Forests       94316
# 4033 Tropical and Subtropical Coniferous Forests       94316
# 4034 Tropical and Subtropical Coniferous Forests       68735
# 4035 Tropical and Subtropical Coniferous Forests       68707
# 4036 Tropical and Subtropical Dry Broadleaf Forests    64872
# 4037 Tropical and Subtropical Coniferous Forests       99019
# 4038 Tropical and Subtropical Dry Broadleaf Forests    64872
# 4039 Tropical and Subtropical Dry Broadleaf Forests    64872
# 4040 Tropical and Subtropical Dry Broadleaf Forests    68717
# 4041 Tropical and Subtropical Coniferous Forests       99026
# 4042 Tropical and Subtropical Coniferous Forests        6712
# 4043 Tropical and Subtropical Coniferous Forests        8407
# 4044 Tropical and Subtropical Coniferous Forests       47076
# 4045 Tropical and Subtropical Coniferous Forests       47076
# 4046 Tropical and Subtropical Coniferous Forests       93575
# 4047 Tropical and Subtropical Coniferous Forests       94259
# 4048 Tropical and Subtropical Coniferous Forests       68805
# 4049 Tropical and Subtropical Coniferous Forests       94237
# 4050 Tropical and Subtropical Dry Broadleaf Forests    47011
# 4051 Tropical and Subtropical Dry Broadleaf Forests    47144
# 4052 Tropical and Subtropical Dry Broadleaf Forests    69004
# 4053 Tropical and Subtropical Dry Broadleaf Forests    69004
# 4054 Tropical and Subtropical Dry Broadleaf Forests    94316
# 4055 Tropical and Subtropical Coniferous Forests       94316
# 4056 Tropical and Subtropical Dry Broadleaf Forests   110587
# 4057 Tropical and Subtropical Dry Broadleaf Forests   110587
# 4058 Tropical and Subtropical Coniferous Forests       68663
# 4059 Tropical and Subtropical Coniferous Forests       68699
# 4060 Tropical and Subtropical Dry Broadleaf Forests   107379
# 4061 Tropical and Subtropical Dry Broadleaf Forests   107379
#      name                                                           covid2
# 1    PASTIZAL CULTIVADO                                             8020
# 2    VEGETACIÓN SECUNDARIA ARBÓREA DE SELVA MEDIANA SUBPERENNIFOLIA 8020
# 3    NO EMPATA                                                        NA
# 4    MANGLAR                                                          NA
# 5    NO EMPATA                                                        NA
# 6    NO EMPATA                                                      8045
# 7    PASTIZAL CULTIVADO                                             7812
# 8    SIN VEGETACIÓN APARENTE                                          NA
# 9    AGRICULTURA DE TEMPORAL ANUAL                                  7291
# 10   PASTIZAL CULTIVADO                                             7291
# 11   PASTIZAL CULTIVADO                                             7291
# 12   PASTIZAL CULTIVADO                                             7291
# 13   PASTIZAL CULTIVADO                                             7291
# 14   PASTIZAL CULTIVADO                                             7291
# 15   MANGLAR                                                        8049
# 16   MANGLAR                                                        8048
# 17   VEGETACIÓN SECUNDARIA ARBÓREA DE SELVA MEDIANA SUBPERENNIFOLIA 7812
# 18   PASTIZAL CULTIVADO                                             7812
# 19   PASTIZAL CULTIVADO                                             8112
# 20   AGRICULTURA DE TEMPORAL ANUAL                                  7291
# 21   PASTIZAL CULTIVADO                                             7291
# 22   PASTIZAL CULTIVADO                                             7291
# 23   PASTIZAL CULTIVADO                                             7291
# 24   PASTIZAL CULTIVADO                                             7291
# 25   PASTIZAL CULTIVADO                                             7291
# 26   PASTIZAL CULTIVADO                                             7291
# 27   PASTIZAL CULTIVADO                                             7291
# 28   VEGETACIÓN HALÓFILA HIDRÓFILA                                  8049
# 29   MANGLAR                                                        8048
# 30   PASTIZAL CULTIVADO                                             7812
# ⋮    ⋮                                                              ⋮
# 4032 VEGETACIÓN SECUNDARIA ARBUSTIVA DE BOSQUE DE ENCINO            11155
# 4033 VEGETACIÓN SECUNDARIA ARBUSTIVA DE BOSQUE DE ENCINO            11267
# 4034 AGRICULTURA DE TEMPORAL ANUAL                                  11267
# 4035 AGRICULTURA DE TEMPORAL ANUAL                                  11267
# 4036 SELVA BAJA CADUCIFOLIA                                         10897
# 4037 VEGETACIÓN SECUNDARIA ARBÓREA DE BOSQUE DE ENCINO-PINO         11244
# 4038 SELVA BAJA CADUCIFOLIA                                         10897
# 4039 SELVA BAJA CADUCIFOLIA                                         10897
# 4040 AGRICULTURA DE TEMPORAL ANUAL                                  11244
# 4041 VEGETACIÓN SECUNDARIA ARBÓREA DE BOSQUE DE ENCINO-PINO         11295
# 4042 BOSQUE DE PINO                                                 11295
# 4043 BOSQUE DE PINO-ENCINO                                          11295
# 4044 PASTIZAL INDUCIDO                                              11156
# 4045 PASTIZAL INDUCIDO                                              11156
# 4046 VEGETACIÓN SECUNDARIA ARBÓREA DE BOSQUE DE PINO-ENCINO         11405
# 4047 VEGETACIÓN SECUNDARIA ARBUSTIVA DE BOSQUE DE ENCINO            11385
# 4048 AGRICULTURA DE TEMPORAL ANUAL                                  11151
# 4049 VEGETACIÓN SECUNDARIA ARBUSTIVA DE BOSQUE DE ENCINO            11385
# 4050 PASTIZAL INDUCIDO                                              11392
# 4051 PASTIZAL INDUCIDO                                              11373
# 4052 AGRICULTURA DE TEMPORAL ANUAL                                  11382
# 4053 AGRICULTURA DE TEMPORAL ANUAL                                  11382
# 4054 VEGETACIÓN SECUNDARIA ARBUSTIVA DE BOSQUE DE ENCINO            11382
# 4055 VEGETACIÓN SECUNDARIA ARBUSTIVA DE BOSQUE DE ENCINO            10897
# 4056 VEGETACIÓN SECUNDARIA ARBÓREA DE SELVA BAJA CADUCIFOLIA        10897
# 4057 VEGETACIÓN SECUNDARIA ARBÓREA DE SELVA BAJA CADUCIFOLIA        11244
# 4058 AGRICULTURA DE TEMPORAL ANUAL                                  11244
# 4059 AGRICULTURA DE TEMPORAL ANUAL                                  10897
# 4060 VEGETACIÓN SECUNDARIA ARBUSTIVA DE SELVA BAJA CADUCIFOLIA      10897
# 4061 VEGETACIÓN SECUNDARIA ARBUSTIVA DE SELVA BAJA CADUCIFOLIA      10897
#      tipos                   geometry
# 1    Selva Alta Perennifolia POINT (-97.651563416 21.467389801)
# 2    Selva Alta Perennifolia POINT (-97.602563416 21.467389801)
# 3    NaN                     POINT (-97.553563416 21.467389801)
# 4    NaN                     POINT (-97.504563416 21.467389801)
# 5    NaN                     POINT (-97.455563416 21.467389801)
# 6    Pastizal Cultivado      POINT (-97.406563416 21.467389801)
# 7    Pastizal Cultivado      POINT (-97.3644320579 21.469261601)
# 8    NaN                     POINT (-97.2293390727 21.4724816044)
# 9    Pastizal Cultivado      POINT (-97.79856341599999 21.418389801)
# 10   Pastizal Cultivado      POINT (-97.749563416 21.418389801)
# 11   Pastizal Cultivado      POINT (-97.70056341599999 21.418389801)
# 12   Pastizal Cultivado      POINT (-97.651563416 21.418389801)
# 13   Pastizal Cultivado      POINT (-97.602563416 21.418389801)
# 14   Pastizal Cultivado      POINT (-97.553563416 21.418389801)
# 15   Manglar                 POINT (-97.504563416 21.418389801)
# 16   Manglar                 POINT (-97.455563416 21.418389801)
# 17   Pastizal Cultivado      POINT (-97.406563416 21.418389801)
# 18   Pastizal Cultivado      POINT (-97.3733748276 21.4241822337)
# 19   Selva Alta Perennifolia POINT (-97.945563416 21.369389801)
# 20   Pastizal Cultivado      POINT (-97.89656341600001 21.369389801)
# 21   Pastizal Cultivado      POINT (-97.847563416 21.369389801)
# 22   Pastizal Cultivado      POINT (-97.79856341599999 21.369389801)
# 23   Pastizal Cultivado      POINT (-97.749563416 21.369389801)
# 24   Pastizal Cultivado      POINT (-97.70056341599999 21.369389801)
# 25   Pastizal Cultivado      POINT (-97.651563416 21.369389801)
# 26   Pastizal Cultivado      POINT (-97.602563416 21.369389801)
# 27   Pastizal Cultivado      POINT (-97.553563416 21.369389801)
# 28   Manglar                 POINT (-97.504563416 21.369389801)
# 29   Manglar                 POINT (-97.455563416 21.369389801)
# 30   Pastizal Cultivado      POINT (-97.41159098030001 21.3726158808)
# ⋮    ⋮                       ⋮
# 4032 Bosque de Encino        POINT (-97.210563416 17.547389801)
# 4033 Agricultura de Temporal POINT (-97.16156341600001 17.547389801)
# 4034 Agricultura de Temporal POINT (-97.112563416 17.547389801)
# 4035 Agricultura de Temporal POINT (-97.06356341599999 17.547389801)
# 4036 Selva Baja Caducifolia  POINT (-97.014563416 17.547389801)
# 4037 Bosque de Encino        POINT (-96.96556341599999 17.547389801)
# 4038 Selva Baja Caducifolia  POINT (-96.916563416 17.547389801)
# 4039 Selva Baja Caducifolia  POINT (-96.867563416 17.547389801)
# 4040 Bosque de Encino        POINT (-96.818563416 17.547389801)
# 4041 Bosque de Pino          POINT (-96.769563416 17.547389801)
# 4042 Bosque de Pino          POINT (-96.720563416 17.547389801)
# 4043 Bosque de Pino          POINT (-96.671563416 17.547389801)
# 4044 Agricultura de Temporal POINT (-97.651563416 17.498389801)
# 4045 Agricultura de Temporal POINT (-97.602563416 17.498389801)
# 4046 Agricultura de Riego    POINT (-97.553563416 17.498389801)
# 4047 Bosque de Encino        POINT (-97.504563416 17.498389801)
# 4048 Agricultura de Temporal POINT (-97.455563416 17.498389801)
# 4049 Bosque de Encino        POINT (-97.406563416 17.498389801)
# 4050 Agricultura de Riego    POINT (-97.357563416 17.498389801)
# 4051 Chaparral               POINT (-97.308563416 17.498389801)
# 4052 Chaparral               POINT (-97.25956341600001 17.498389801)
# 4053 Chaparral               POINT (-97.210563416 17.498389801)
# 4054 Chaparral               POINT (-97.16156341600001 17.498389801)
# 4055 Selva Baja Caducifolia  POINT (-97.112563416 17.498389801)
# 4056 Selva Baja Caducifolia  POINT (-97.06356341599999 17.498389801)
# 4057 Bosque de Encino        POINT (-97.014563416 17.498389801)
# 4058 Bosque de Encino        POINT (-96.96556341599999 17.498389801)
# 4059 Selva Baja Caducifolia  POINT (-96.916563416 17.498389801)
# 4060 Selva Baja Caducifolia  POINT (-96.867563416 17.498389801)
# 4061 Selva Baja Caducifolia  POINT (-96.818563416 17.498389801)

# %%
model.sample <-S.CARbym(formula=formula_sample,family="binomial",W=M_bis,trials = trials,data=DataFrame,burnin=burnin,n.sample=n.sample,thin=thin,verbose = TRUE)
# Out:
# Setting up the model.
# Generating 1000 post burnin and thinned (if requested) samples.
#   |======================================================================| 100%
# Summarising results.
# Finished in  846.8 seconds.

# %%
model.presence <- S.CARbym(formula=formula_presence,family="binomial",W=M_bis,trials = trials,data=DataFrame,burnin=burnin,n.sample=n.sample,thin=thin,verbose = TRUE)
# Out:
# Setting up the model.
# Generating 1000 post burnin and thinned (if requested) samples.
#   |======================================================================| 100%
# Summarising results.
# Finished in  866.1 seconds.

# %%
#DIC for model with polygon 4 611.3458
print(model.sample)
# Out:
# #################
# #### Model fitted
# #################
# Likelihood model - Binomial (logit link function)
# Random effects model - BYM CAR
# Regression equation - sample ~ Disttoroadm + Populationm
# Number of missing observations - 731
#
# ############
# #### Results
# ############
# Posterior quantities and DIC
#
#              Median    2.5%   97.5% n.sample % accept n.effective Geweke.diag
# (Intercept)  3.5183  2.8552  4.5571     1000     46.3        17.8         0.6
# Disttoroadm -0.0002 -0.0004 -0.0001     1000     46.3       530.0         1.0
# Populationm  0.0000 -0.0001  0.0002     1000     46.3      1000.0        -0.1
# tau2         6.6524  3.7867 11.9560     1000    100.0        26.7        -0.1
# sigma2       0.4145  0.0551  3.3149     1000    100.0         5.0         1.0
#
# DIC =  2092.947       p.d =  543.3697       LMPL =  -1111.51

# %%
print(model.presence)
# Out:
# #################
# #### Model fitted
# #################
# Likelihood model - Binomial (logit link function)
# Random effects model - BYM CAR
# Regression equation - species ~ Elevationm + MeanTempm
# Number of missing observations - 1161
#
# ############
# #### Results
# ############
# Posterior quantities and DIC
#
#              Median    2.5%   97.5% n.sample % accept n.effective Geweke.diag
# (Intercept) -4.4071 -6.1465 -3.1003     1000     46.5        32.6         1.7
# Elevationm   0.0002 -0.0001  0.0005     1000     46.5       701.9         1.0
# MeanTempm   -0.0007 -0.0012 -0.0002     1000     46.5       297.3         0.6
# tau2        14.7050  7.1535 31.7971     1000    100.0        12.6        -1.4
# sigma2       0.0930  0.0331  0.4415     1000    100.0         9.1        -0.9
#
# DIC =  1420.211       p.d =  441.4069       LMPL =  -786.85

# %%
## Compute independent joint distribution
library(boot)
## Calculate the inverse of the logit for extracted fitted 
#fitted_presences = apply(model.presence$samples$fitted,MARGIN=1,inv.logit)
#fitted_sample = apply(model.sample$samples$fitted,MARGIN=1,inv.logit)

fitted_presences = apply(model.presence$samples$fitted,MARGIN=1,identity)
fitted_sample = apply(model.sample$samples$fitted,MARGIN=1,identity)

re_presence = apply(model.presence$samples$psi,MARGIN=1,identity)
re_sample = apply(model.sample$samples$psi,MARGIN=1,identity)

# %%
getUpperLowerCI <- function(fitted_sample,prefix="",MARGIN=1){
    fp = partial(quantile,probs=c(0.025,0.5,0.975))
    quants =apply(X = fitted_sample,FUN = fp,MARGIN)
    mfitt = apply(fitted_sample,mean,MARGIN = MARGIN)
    vfitt = apply(fitted_sample,var,MARGIN = MARGIN)
    new_data = cbind(t(quants),mfitt,vfitt)
    l = as.list(c("q025","median","q0975","mean","variance"))
    nnames = lapply(l,function (x){return(paste(prefix,x,sep = '_'))})
    colnames(new_data) = nnames
    return(new_data)
}

# %%
## Sample from the posterior
sample.y <- data.frame(t(fitted_presences)) %>% mutate_all(function(p) rbernoulli(1,p))
sample.x <- data.frame(t(fitted_sample)) %>% mutate_all(function(p) rbernoulli(1,p))
sum.x <- colSums(sample.x)
nsample <- nrow(sample.x)
PX <- sum.x / nsample
sum.y <- colSums(sample.y)
PY <- sum.y / nsample
PXY <- PX * PY

# %%
P = getUpperLowerCI(fitted_presences,prefix = 'P')
S = getUpperLowerCI(fitted_sample,prefix = 'S')
Gp = getUpperLowerCI(re_presence,prefix = 'Gp')
Gs = getUpperLowerCI(re_sample,prefix = 'Gs')

# %%
dataout = cbind(TDF$cellids,P,S,Gp,Gs,PX,PY,PXY)

# %%
## Save the complete chain trace for analysing in Python,
file_ = '/outputs/presence_only_models/modelCAR1.csv'
write.csv(dataout,file_)

# %% [markdown]
# ### Postprocess the posterior dist.

# %%
joint_ind_ps_summary = getUpperLowerCI(joint_ind_ps,prefix='join_ind_ps',MARGIN=1)

# %%
var_joint_ind_ps_summary = getUpperLowerCI(var_joint_ind_ps,prefix='var_joint',MARGIN=1)

# %%
sample_ci = getUpperLowerCI(model.sample$samples$fitted,prefix = 'sample')

# %%
presence_ci = getUpperLowerCI(model.presence$samples$fitted,prefix='pinophyta')

# %%
#TDF$fitted_values = model.spatial$fitted.values
#TDF = cbind(TDF,joint_ind_ps_summary,var_joint_ind_ps_summary,sample_ci,presence_ci)
TDF = cbind(TDF,joint_ind_ps_summary,var_joint_ind_ps_summary)

# %%
## Export to CSV
write.csv(TDF,file='/outputs/resultsCAR_sampleeffort1_puebla_p9_pinophyta_luca.csv')

# %%
HASTA AQUI ME QUEDE HOY. FALTA VER que pasa con los modelos hacer mapa

# %%
dtau = density(model.presence$samples$tau2)
dsigma = density(model.presence$samples$sigma2)

plot(dtau,main=expression(tau^2))
plot(dsigma,main=expression(sigma^2))
plot(beta1,main="Intercept")
plot(beta2,main="Distance to Road")
plot(beta3,main="Population")

# %%
mod_sig = glm(formula, data=TDF, family=binomial())
#mod1.summary()

# %%
summary(mod_sig)

# %%
confint(mod_sig)

# %% [markdown]
# ## Instantiate Geospatial data

# %%
library(lattice)
library(sp)

# %%
coordinates(TDF) <- c("Longitude","Latitude")

# %%
bubble(TDF,"Pinophyta")

# %% [markdown]
# ## Spatial analysis in R
# First, exploratory

# %%
library(gstat)

# %%
plot(variogram(Pinophyta ~ 1,TDF))

# %%
install.packages("geoR")

# %%
install.packages("geoRglm")

# %%
library('spdep')

# %%
model_car = spautolm(Pinophyta ~ Dist.to.road_m +  Population_m + tipos,data=TDF,family="CAR")
